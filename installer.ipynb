# %%
# %pip install numpy pandas scipy
# Out:
# Requirement already satisfied: numpy in d:\conda_envs\my_env\Lib\site-packages (2.1.3)
# Requirement already satisfied: pandas in d:\conda_envs\my_env\Lib\site-packages (3.0.3)
# Requirement already satisfied: scipy in d:\conda_envs\my_env\Lib\site-packages (1.16.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\conda_envs\my_env\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in d:\conda_envs\my_env\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in d:\conda_envs\my_env\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)

# %%
# %pip install matplotlib plotly
# Out:
# Requirement already satisfied: matplotlib in d:\conda_envs\my_env\Lib\site-packages (3.10.9)
# Requirement already satisfied: plotly in d:\conda_envs\my_env\Lib\site-packages (6.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: narwhals>=1.15.1 in d:\conda_envs\my_env\Lib\site-packages (from plotly) (2.21.0)
# Requirement already satisfied: six>=1.5 in d:\conda_envs\my_env\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)

# %%
# %pip install scikit-learn xgboost lightgbm catboost
# Out:
# Requirement already satisfied: scikit-learn in d:\conda_envs\my_env\Lib\site-packages (1.7.2)
# Requirement already satisfied: xgboost in d:\conda_envs\my_env\Lib\site-packages (3.1.3)
# Requirement already satisfied: lightgbm in d:\conda_envs\my_env\Lib\site-packages (4.6.0)
# Requirement already satisfied: catboost in d:\conda_envs\my_env\Lib\site-packages (1.2.10)
# Requirement already satisfied: numpy>=1.22.0 in d:\conda_envs\my_env\Lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.8.0 in d:\conda_envs\my_env\Lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\conda_envs\my_env\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\conda_envs\my_env\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: graphviz in d:\conda_envs\my_env\Lib\site-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in d:\conda_envs\my_env\Lib\site-packages (from catboost) (3.10.9)
# Requirement already satisfied: pandas<4.0,>=0.24 in d:\conda_envs\my_env\Lib\site-packages (from catboost) (3.0.3)
# Requirement already satisfied: plotly in d:\conda_envs\my_env\Lib\site-packages (from catboost) (6.7.0)
# Requirement already satisfied: six in d:\conda_envs\my_env\Lib\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\conda_envs\my_env\Lib\site-packages (from pandas<4.0,>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: tzdata in d:\conda_envs\my_env\Lib\site-packages (from pandas<4.0,>=0.24->catboost) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib->catboost) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib->catboost) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib->catboost) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib->catboost) (3.3.2)
# Requirement already satisfied: narwhals>=1.15.1 in d:\conda_envs\my_env\Lib\site-packages (from plotly->catboost) (2.21.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)

# %%
# %pip install ta
# Out:
# Collecting ta
#   Downloading ta-0.11.0.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in d:\conda_envs\my_env\Lib\site-packages (from ta) (2.1.3)
# Requirement already satisfied: pandas in d:\conda_envs\my_env\Lib\site-packages (from ta) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\conda_envs\my_env\Lib\site-packages (from pandas->ta) (2.9.0.post0)
# Requirement already satisfied: tzdata in d:\conda_envs\my_env\Lib\site-packages (from pandas->ta) (2026.2)
# Requirement already satisfied: six>=1.5 in d:\conda_envs\my_env\Lib\site-packages (from python-dateutil>=2.8.2->pandas->ta) (1.17.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (pyproject.toml): started
#   Building wheel for ta (pyproject.toml): finished with status 'done'
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29497 sha256=2d7854988fc86b0679ab3c5629100f867b2269762b5a71de0fed2f5452704396
#   Stored in directory: c:\users\narak\appdata\local\pip\cache\wheels\a1\d7\29\7781cc5eb9a3659d032d7d15bdd0f49d07d2b24fec29f44bc4
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.11.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)

# %%
# %pip install shap
# Out:
# Requirement already satisfied: shap in d:\conda_envs\my_env\Lib\site-packages (0.51.0)
# Requirement already satisfied: numpy>=2 in d:\conda_envs\my_env\Lib\site-packages (from shap) (2.1.3)
# Requirement already satisfied: scipy in d:\conda_envs\my_env\Lib\site-packages (from shap) (1.16.3)
# Requirement already satisfied: scikit-learn in d:\conda_envs\my_env\Lib\site-packages (from shap) (1.7.2)
# Requirement already satisfied: pandas in d:\conda_envs\my_env\Lib\site-packages (from shap) (3.0.3)
# Requirement already satisfied: tqdm>=4.27.0 in d:\conda_envs\my_env\Lib\site-packages (from shap) (4.68.1)
# Requirement already satisfied: packaging>20.9 in d:\conda_envs\my_env\Lib\site-packages (from shap) (25.0)
# Requirement already satisfied: slicer==0.0.8 in d:\conda_envs\my_env\Lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in d:\conda_envs\my_env\Lib\site-packages (from shap) (0.65.1)
# Requirement already satisfied: llvmlite in d:\conda_envs\my_env\Lib\site-packages (from shap) (0.47.0)
# Requirement already satisfied: cloudpickle in d:\conda_envs\my_env\Lib\site-packages (from shap) (3.1.2)
# Requirement already satisfied: typing-extensions in d:\conda_envs\my_env\Lib\site-packages (from shap) (4.15.0)
# Requirement already satisfied: colorama in d:\conda_envs\my_env\Lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\conda_envs\my_env\Lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: tzdata in d:\conda_envs\my_env\Lib\site-packages (from pandas->shap) (2026.2)
# Requirement already satisfied: six>=1.5 in d:\conda_envs\my_env\Lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in d:\conda_envs\my_env\Lib\site-packages (from scikit-learn->shap) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\conda_envs\my_env\Lib\site-packages (from scikit-learn->shap) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)

# %%
# %pip install autogluon.tabular
# Out:
# Requirement already satisfied: autogluon.tabular in d:\conda_envs\my_env\Lib\site-packages (1.5.0)
# Requirement already satisfied: numpy<2.4.0,>=1.25.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.tabular) (2.1.3)
# Requirement already satisfied: scipy<1.17,>=1.5.4 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.tabular) (1.16.3)
# Collecting pandas<2.4.0,>=2.0.0 (from autogluon.tabular)
#   Downloading pandas-2.3.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: scikit-learn<1.8.0,>=1.4.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.tabular) (1.7.2)
# Requirement already satisfied: networkx<4,>=3.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.tabular) (3.6.1)
# Requirement already satisfied: autogluon.core==1.5.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.tabular) (1.5.0)
# Requirement already satisfied: autogluon.features==1.5.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.tabular) (1.5.0)
# Requirement already satisfied: tqdm<5,>=4.38 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.core==1.5.0->autogluon.tabular) (4.68.1)
# Requirement already satisfied: requests in d:\conda_envs\my_env\Lib\site-packages (from autogluon.core==1.5.0->autogluon.tabular) (2.33.1)
# Requirement already satisfied: matplotlib<3.11,>=3.7.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.core==1.5.0->autogluon.tabular) (3.10.9)
# Requirement already satisfied: boto3<2,>=1.10 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.core==1.5.0->autogluon.tabular) (1.43.7)
# Requirement already satisfied: autogluon.common==1.5.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.core==1.5.0->autogluon.tabular) (1.5.0)
# Requirement already satisfied: pyarrow<21.0.0,>=7.0.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.common==1.5.0->autogluon.core==1.5.0->autogluon.tabular) (20.0.0)
# Requirement already satisfied: psutil<7.2.0,>=5.7.3 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.common==1.5.0->autogluon.core==1.5.0->autogluon.tabular) (7.1.3)
# Requirement already satisfied: joblib<1.7,>=1.2 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.common==1.5.0->autogluon.core==1.5.0->autogluon.tabular) (1.5.3)
# Requirement already satisfied: pyyaml>=5.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.common==1.5.0->autogluon.core==1.5.0->autogluon.tabular) (6.0.2)
# Requirement already satisfied: botocore<1.44.0,>=1.43.7 in d:\conda_envs\my_env\Lib\site-packages (from boto3<2,>=1.10->autogluon.core==1.5.0->autogluon.tabular) (1.43.7)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in d:\conda_envs\my_env\Lib\site-packages (from boto3<2,>=1.10->autogluon.core==1.5.0->autogluon.tabular) (1.1.0)
# Requirement already satisfied: s3transfer<0.18.0,>=0.17.0 in d:\conda_envs\my_env\Lib\site-packages (from boto3<2,>=1.10->autogluon.core==1.5.0->autogluon.tabular) (0.17.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in d:\conda_envs\my_env\Lib\site-packages (from botocore<1.44.0,>=1.43.7->boto3<2,>=1.10->autogluon.core==1.5.0->autogluon.tabular) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in d:\conda_envs\my_env\Lib\site-packages (from botocore<1.44.0,>=1.43.7->boto3<2,>=1.10->autogluon.core==1.5.0->autogluon.tabular) (2.6.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular) (25.0)
# Requirement already satisfied: pillow>=8 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.tabular) (3.3.2)
# Requirement already satisfied: pytz>=2020.1 in d:\conda_envs\my_env\Lib\site-packages (from pandas<2.4.0,>=2.0.0->autogluon.tabular) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\conda_envs\my_env\Lib\site-packages (from pandas<2.4.0,>=2.0.0->autogluon.tabular) (2026.2)
# Requirement already satisfied: six>=1.5 in d:\conda_envs\my_env\Lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.44.0,>=1.43.7->boto3<2,>=1.10->autogluon.core==1.5.0->autogluon.tabular) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\conda_envs\my_env\Lib\site-packages (from scikit-learn<1.8.0,>=1.4.0->autogluon.tabular) (3.6.0)
# Requirement already satisfied: colorama in d:\conda_envs\my_env\Lib\site-packages (from tqdm<5,>=4.38->autogluon.core==1.5.0->autogluon.tabular) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\conda_envs\my_env\Lib\site-packages (from requests->autogluon.core==1.5.0->autogluon.tabular) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\conda_envs\my_env\Lib\site-packages (from requests->autogluon.core==1.5.0->autogluon.tabular) (3.13)
# Requirement already satisfied: certifi>=2023.5.7 in d:\conda_envs\my_env\Lib\site-packages (from requests->autogluon.core==1.5.0->autogluon.tabular) (2026.4.22)
# Downloading pandas-2.3.3-cp311-cp311-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    -------- ------------------------------- 2.4/11.3 MB 19.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.7/11.3 MB 30.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 29.6 MB/s  0:00:00
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 3.0.3
#     Uninstalling pandas-3.0.3:
#       Successfully uninstalled pandas-3.0.3
# Successfully installed pandas-2.3.3
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'D:\conda_envs\my_env\Lib\site-packages\~-ndas.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'D:\conda_envs\my_env\Lib\site-packages\~.ndas'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-multimodal 1.5.0 requires Pillow<12,>=10.0.1, but you have pillow 12.2.0 which is incompatible.
# autogluon-multimodal 1.5.0 requires torch<2.10,>=2.6, but you have torch 2.5.1+cu121 which is incompatible.
# autogluon-multimodal 1.5.0 requires torchvision<0.25.0,>=0.21.0, but you have torchvision 0.20.1+cu121 which is incompatible.
# autogluon-timeseries 1.5.0 requires torch<2.10,>=2.6, but you have torch 2.5.1+cu121 which is incompatible.
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)

# %%
# %pip install autogluon.timeseries
# Out:
# Requirement already satisfied: autogluon.timeseries in d:\conda_envs\my_env\Lib\site-packages (1.5.0)
# Requirement already satisfied: joblib<1.7,>=1.2 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (1.5.3)
# Requirement already satisfied: numpy<2.4.0,>=1.25.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (2.1.3)
# Requirement already satisfied: scipy<1.17,>=1.5.4 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (1.16.3)
# Requirement already satisfied: pandas<2.4.0,>=2.0.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (2.3.3)
# Collecting torch<2.10,>=2.6 (from autogluon.timeseries)
#   Downloading torch-2.9.1-cp311-cp311-win_amd64.whl.metadata (30 kB)
# Requirement already satisfied: lightning<2.6,>=2.5.1 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (2.5.6)
# Requirement already satisfied: transformers<4.58,>=4.51.0 in d:\conda_envs\my_env\Lib\site-packages (from transformers[sentencepiece]<4.58,>=4.51.0->autogluon.timeseries) (4.57.6)
# Requirement already satisfied: accelerate<2.0,>=0.34.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (1.13.0)
# Requirement already satisfied: gluonts<0.17,>=0.15.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (0.16.2)
# Requirement already satisfied: networkx<4,>=3.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (3.6.1)
# Requirement already satisfied: statsforecast<2.0.2,>=1.7.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (2.0.1)
# Requirement already satisfied: mlforecast<0.15.0,>=0.14.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (0.14.0)
# Requirement already satisfied: utilsforecast<0.2.12,>=0.2.3 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (0.2.11)
# Requirement already satisfied: coreforecast<0.0.17,>=0.0.12 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (0.0.16)
# Requirement already satisfied: fugue>=0.9.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (0.9.7)
# Requirement already satisfied: tqdm<5,>=4.38 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (4.68.1)
# Requirement already satisfied: orjson~=3.9 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (3.11.9)
# Requirement already satisfied: einops<1,>=0.7 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (0.8.2)
# Requirement already satisfied: chronos-forecasting<2.4,>=2.2.2 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (2.2.2)
# Requirement already satisfied: peft<0.18,>=0.13.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (0.17.1)
# Requirement already satisfied: tensorboard<3,>=2.9 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (2.20.0)
# Requirement already satisfied: autogluon.core==1.5.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (1.5.0)
# Requirement already satisfied: autogluon.common==1.5.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (1.5.0)
# Requirement already satisfied: autogluon.features==1.5.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.timeseries) (1.5.0)
# Requirement already satisfied: autogluon.tabular==1.5.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.tabular[catboost,lightgbm,xgboost]==1.5.0->autogluon.timeseries) (1.5.0)
# Requirement already satisfied: pyarrow<21.0.0,>=7.0.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.common==1.5.0->autogluon.timeseries) (20.0.0)
# Requirement already satisfied: boto3<2,>=1.10 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.common==1.5.0->autogluon.timeseries) (1.43.7)
# Requirement already satisfied: psutil<7.2.0,>=5.7.3 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.common==1.5.0->autogluon.timeseries) (7.1.3)
# Requirement already satisfied: requests in d:\conda_envs\my_env\Lib\site-packages (from autogluon.common==1.5.0->autogluon.timeseries) (2.33.1)
# Requirement already satisfied: pyyaml>=5.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.common==1.5.0->autogluon.timeseries) (6.0.2)
# Requirement already satisfied: scikit-learn<1.8.0,>=1.4.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.core==1.5.0->autogluon.timeseries) (1.7.2)
# Requirement already satisfied: matplotlib<3.11,>=3.7.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.core==1.5.0->autogluon.timeseries) (3.10.9)
# Requirement already satisfied: lightgbm<4.7,>=4.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.tabular[catboost,lightgbm,xgboost]==1.5.0->autogluon.timeseries) (4.6.0)
# Requirement already satisfied: catboost<1.3,>=1.2 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.tabular[catboost,lightgbm,xgboost]==1.5.0->autogluon.timeseries) (1.2.10)
# Requirement already satisfied: xgboost<3.2,>=2.0 in d:\conda_envs\my_env\Lib\site-packages (from autogluon.tabular[catboost,lightgbm,xgboost]==1.5.0->autogluon.timeseries) (3.1.3)
# Requirement already satisfied: packaging>=20.0 in d:\conda_envs\my_env\Lib\site-packages (from accelerate<2.0,>=0.34.0->autogluon.timeseries) (25.0)
# Requirement already satisfied: huggingface_hub>=0.21.0 in d:\conda_envs\my_env\Lib\site-packages (from accelerate<2.0,>=0.34.0->autogluon.timeseries) (0.36.2)
# Requirement already satisfied: safetensors>=0.4.3 in d:\conda_envs\my_env\Lib\site-packages (from accelerate<2.0,>=0.34.0->autogluon.timeseries) (0.7.0)
# Requirement already satisfied: botocore<1.44.0,>=1.43.7 in d:\conda_envs\my_env\Lib\site-packages (from boto3<2,>=1.10->autogluon.common==1.5.0->autogluon.timeseries) (1.43.7)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in d:\conda_envs\my_env\Lib\site-packages (from boto3<2,>=1.10->autogluon.common==1.5.0->autogluon.timeseries) (1.1.0)
# Requirement already satisfied: s3transfer<0.18.0,>=0.17.0 in d:\conda_envs\my_env\Lib\site-packages (from boto3<2,>=1.10->autogluon.common==1.5.0->autogluon.timeseries) (0.17.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in d:\conda_envs\my_env\Lib\site-packages (from botocore<1.44.0,>=1.43.7->boto3<2,>=1.10->autogluon.common==1.5.0->autogluon.timeseries) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in d:\conda_envs\my_env\Lib\site-packages (from botocore<1.44.0,>=1.43.7->boto3<2,>=1.10->autogluon.common==1.5.0->autogluon.timeseries) (2.6.3)
# Requirement already satisfied: graphviz in d:\conda_envs\my_env\Lib\site-packages (from catboost<1.3,>=1.2->autogluon.tabular[catboost,lightgbm,xgboost]==1.5.0->autogluon.timeseries) (0.21)
# Requirement already satisfied: plotly in d:\conda_envs\my_env\Lib\site-packages (from catboost<1.3,>=1.2->autogluon.tabular[catboost,lightgbm,xgboost]==1.5.0->autogluon.timeseries) (6.7.0)
# Requirement already satisfied: six in d:\conda_envs\my_env\Lib\site-packages (from catboost<1.3,>=1.2->autogluon.tabular[catboost,lightgbm,xgboost]==1.5.0->autogluon.timeseries) (1.17.0)
# Requirement already satisfied: pydantic<3,>=1.7 in d:\conda_envs\my_env\Lib\site-packages (from gluonts<0.17,>=0.15.0->autogluon.timeseries) (2.13.4)
# Requirement already satisfied: toolz~=0.10 in d:\conda_envs\my_env\Lib\site-packages (from gluonts<0.17,>=0.15.0->autogluon.timeseries) (0.12.1)
# Requirement already satisfied: typing-extensions~=4.0 in d:\conda_envs\my_env\Lib\site-packages (from gluonts<0.17,>=0.15.0->autogluon.timeseries) (4.15.0)
# Requirement already satisfied: fsspec<2027.0,>=2022.5.0 in d:\conda_envs\my_env\Lib\site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning<2.6,>=2.5.1->autogluon.timeseries) (2025.3.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in d:\conda_envs\my_env\Lib\site-packages (from lightning<2.6,>=2.5.1->autogluon.timeseries) (0.15.3)
# Requirement already satisfied: torchmetrics<3.0,>0.7.0 in d:\conda_envs\my_env\Lib\site-packages (from lightning<2.6,>=2.5.1->autogluon.timeseries) (1.7.4)
# Requirement already satisfied: pytorch-lightning in d:\conda_envs\my_env\Lib\site-packages (from lightning<2.6,>=2.5.1->autogluon.timeseries) (2.6.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in d:\conda_envs\my_env\Lib\site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning<2.6,>=2.5.1->autogluon.timeseries) (3.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.timeseries) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.timeseries) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.timeseries) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.timeseries) (1.5.0)
# Requirement already satisfied: pillow>=8 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.timeseries) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in d:\conda_envs\my_env\Lib\site-packages (from matplotlib<3.11,>=3.7.0->autogluon.core==1.5.0->autogluon.timeseries) (3.3.2)
# Requirement already satisfied: cloudpickle in d:\conda_envs\my_env\Lib\site-packages (from mlforecast<0.15.0,>=0.14.0->autogluon.timeseries) (3.1.2)
# Requirement already satisfied: numba in d:\conda_envs\my_env\Lib\site-packages (from mlforecast<0.15.0,>=0.14.0->autogluon.timeseries) (0.65.1)
# Requirement already satisfied: optuna in d:\conda_envs\my_env\Lib\site-packages (from mlforecast<0.15.0,>=0.14.0->autogluon.timeseries) (4.9.0)
# Requirement already satisfied: window-ops in d:\conda_envs\my_env\Lib\site-packages (from mlforecast<0.15.0,>=0.14.0->autogluon.timeseries) (0.0.15)
# Requirement already satisfied: pytz>=2020.1 in d:\conda_envs\my_env\Lib\site-packages (from pandas<2.4.0,>=2.0.0->autogluon.timeseries) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\conda_envs\my_env\Lib\site-packages (from pandas<2.4.0,>=2.0.0->autogluon.timeseries) (2026.2)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\conda_envs\my_env\Lib\site-packages (from pydantic<3,>=1.7->gluonts<0.17,>=0.15.0->autogluon.timeseries) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\conda_envs\my_env\Lib\site-packages (from pydantic<3,>=1.7->gluonts<0.17,>=0.15.0->autogluon.timeseries) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\conda_envs\my_env\Lib\site-packages (from pydantic<3,>=1.7->gluonts<0.17,>=0.15.0->autogluon.timeseries) (0.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\conda_envs\my_env\Lib\site-packages (from scikit-learn<1.8.0,>=1.4.0->autogluon.core==1.5.0->autogluon.timeseries) (3.6.0)
# Requirement already satisfied: statsmodels>=0.13.2 in d:\conda_envs\my_env\Lib\site-packages (from statsforecast<2.0.2,>=1.7.0->autogluon.timeseries) (0.14.6)
# Requirement already satisfied: absl-py>=0.4 in d:\conda_envs\my_env\Lib\site-packages (from tensorboard<3,>=2.9->autogluon.timeseries) (2.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in d:\conda_envs\my_env\Lib\site-packages (from tensorboard<3,>=2.9->autogluon.timeseries) (1.80.0)
# Requirement already satisfied: markdown>=2.6.8 in d:\conda_envs\my_env\Lib\site-packages (from tensorboard<3,>=2.9->autogluon.timeseries) (3.10.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in d:\conda_envs\my_env\Lib\site-packages (from tensorboard<3,>=2.9->autogluon.timeseries) (6.33.6)
# Requirement already satisfied: setuptools>=41.0.0 in d:\conda_envs\my_env\Lib\site-packages (from tensorboard<3,>=2.9->autogluon.timeseries) (70.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\conda_envs\my_env\Lib\site-packages (from tensorboard<3,>=2.9->autogluon.timeseries) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\conda_envs\my_env\Lib\site-packages (from tensorboard<3,>=2.9->autogluon.timeseries) (3.1.8)
# Requirement already satisfied: filelock in d:\conda_envs\my_env\Lib\site-packages (from torch<2.10,>=2.6->autogluon.timeseries) (3.29.0)
# Collecting sympy>=1.13.3 (from torch<2.10,>=2.6->autogluon.timeseries)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: jinja2 in d:\conda_envs\my_env\Lib\site-packages (from torch<2.10,>=2.6->autogluon.timeseries) (3.1.6)
# Requirement already satisfied: colorama in d:\conda_envs\my_env\Lib\site-packages (from tqdm<5,>=4.38->autogluon.timeseries) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in d:\conda_envs\my_env\Lib\site-packages (from transformers<4.58,>=4.51.0->transformers[sentencepiece]<4.58,>=4.51.0->autogluon.timeseries) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in d:\conda_envs\my_env\Lib\site-packages (from transformers<4.58,>=4.51.0->transformers[sentencepiece]<4.58,>=4.51.0->autogluon.timeseries) (0.22.2)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in d:\conda_envs\my_env\Lib\site-packages (from transformers[sentencepiece]<4.58,>=4.51.0->autogluon.timeseries) (0.2.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\conda_envs\my_env\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<2.6,>=2.5.1->autogluon.timeseries) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\conda_envs\my_env\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<2.6,>=2.5.1->autogluon.timeseries) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\conda_envs\my_env\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<2.6,>=2.5.1->autogluon.timeseries) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\conda_envs\my_env\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<2.6,>=2.5.1->autogluon.timeseries) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\conda_envs\my_env\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<2.6,>=2.5.1->autogluon.timeseries) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in d:\conda_envs\my_env\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<2.6,>=2.5.1->autogluon.timeseries) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\conda_envs\my_env\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<2.6,>=2.5.1->autogluon.timeseries) (1.23.0)
# Requirement already satisfied: idna>=2.0 in d:\conda_envs\my_env\Lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning<2.6,>=2.5.1->autogluon.timeseries) (3.13)
# Requirement already satisfied: triad>=1.0.1 in d:\conda_envs\my_env\Lib\site-packages (from fugue>=0.9.0->autogluon.timeseries) (1.0.2)
# Requirement already satisfied: adagio>=0.2.6 in d:\conda_envs\my_env\Lib\site-packages (from fugue>=0.9.0->autogluon.timeseries) (0.2.6)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in d:\conda_envs\my_env\Lib\site-packages (from numba->mlforecast<0.15.0,>=0.14.0->autogluon.timeseries) (0.47.0)
# Requirement already satisfied: patsy>=0.5.6 in d:\conda_envs\my_env\Lib\site-packages (from statsmodels>=0.13.2->statsforecast<2.0.2,>=1.7.0->autogluon.timeseries) (1.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\conda_envs\my_env\Lib\site-packages (from sympy>=1.13.3->torch<2.10,>=2.6->autogluon.timeseries) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in d:\conda_envs\my_env\Lib\site-packages (from werkzeug>=1.0.1->tensorboard<3,>=2.9->autogluon.timeseries) (3.0.3)
# Requirement already satisfied: alembic>=1.5.0 in d:\conda_envs\my_env\Lib\site-packages (from optuna->mlforecast<0.15.0,>=0.14.0->autogluon.timeseries) (1.18.4)
# Requirement already satisfied: colorlog in d:\conda_envs\my_env\Lib\site-packages (from optuna->mlforecast<0.15.0,>=0.14.0->autogluon.timeseries) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in d:\conda_envs\my_env\Lib\site-packages (from optuna->mlforecast<0.15.0,>=0.14.0->autogluon.timeseries) (2.0.49)
# Requirement already satisfied: Mako in d:\conda_envs\my_env\Lib\site-packages (from alembic>=1.5.0->optuna->mlforecast<0.15.0,>=0.14.0->autogluon.timeseries) (1.3.12)
# Requirement already satisfied: greenlet>=1 in d:\conda_envs\my_env\Lib\site-packages (from sqlalchemy>=1.4.2->optuna->mlforecast<0.15.0,>=0.14.0->autogluon.timeseries) (3.5.0)
# Requirement already satisfied: narwhals>=1.15.1 in d:\conda_envs\my_env\Lib\site-packages (from plotly->catboost<1.3,>=1.2->autogluon.tabular[catboost,lightgbm,xgboost]==1.5.0->autogluon.timeseries) (2.21.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\conda_envs\my_env\Lib\site-packages (from requests->autogluon.common==1.5.0->autogluon.timeseries) (3.4.7)
# Requirement already satisfied: certifi>=2023.5.7 in d:\conda_envs\my_env\Lib\site-packages (from requests->autogluon.common==1.5.0->autogluon.timeseries) (2026.4.22)
# Downloading torch-2.9.1-cp311-cp311-win_amd64.whl (111.0 MB)
#    ---------------------------------------- 0.0/111.0 MB ? eta -:--:--
#     --------------------------------------- 2.4/111.0 MB 16.8 MB/s eta 0:00:07
#    --- ------------------------------------ 10.2/111.0 MB 30.4 MB/s eta 0:00:04
#    ------ --------------------------------- 19.4/111.0 MB 35.0 MB/s eta 0:00:03
#    ---------- ----------------------------- 28.6/111.0 MB 37.0 MB/s eta 0:00:03
#    ------------- -------------------------- 37.5/111.0 MB 38.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 46.7/111.0 MB 39.1 MB/s eta 0:00:02
#    -------------------- ------------------- 56.9/111.0 MB 40.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 66.1/111.0 MB 40.5 MB/s eta 0:00:02
#    -------------------------- ------------- 72.4/111.0 MB 39.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 82.3/111.0 MB 40.1 MB/s eta 0:00:01
#    -------------------------------- ------- 91.5/111.0 MB 40.5 MB/s eta 0:00:01
#    ----------------------------------- --- 100.1/111.0 MB 40.5 MB/s eta 0:00:01
#    --------------------------------------  108.5/111.0 MB 40.5 MB/s eta 0:00:01
#    --------------------------------------  110.9/111.0 MB 40.2 MB/s eta 0:00:01
#    ---------------------------------------- 111.0/111.0 MB 36.5 MB/s  0:00:03
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 6.3/6.3 MB 38.7 MB/s  0:00:00
# Installing collected packages: sympy, torch
#
#   Attempting uninstall: sympy
#
#     Found existing installation: sympy 1.13.1
#
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#     Uninstalling sympy-1.13.1:
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#       Successfully uninstalled sympy-1.13.1
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#    ---------------------------------------- 0/2 [sympy]
#   Attempting uninstall: torch
#    ---------------------------------------- 0/2 [sympy]
#     Found existing installation: torch 2.5.1+cu121
#    ---------------------------------------- 0/2 [sympy]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#     Uninstalling torch-2.5.1+cu121:
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#       Successfully uninstalled torch-2.5.1+cu121
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    -------------------- ------------------- 1/2 [torch]
#    ---------------------------------------- 2/2 [torch]
#
# Successfully installed sympy-1.14.0 torch-2.9.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-multimodal 1.5.0 requires Pillow<12,>=10.0.1, but you have pillow 12.2.0 which is incompatible.
# autogluon-multimodal 1.5.0 requires torchvision<0.25.0,>=0.21.0, but you have torchvision 0.20.1+cu121 which is incompatible.
# torchaudio 2.5.1+cu121 requires torch==2.5.1+cu121, but you have torch 2.9.1 which is incompatible.
# torchvision 0.20.1+cu121 requires torch==2.5.1+cu121, but you have torch 2.9.1 which is incompatible.
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)

# %%
# %pip install chronos-forecasting
# Out:
# Requirement already satisfied: chronos-forecasting in d:\conda_envs\my_env\Lib\site-packages (2.2.2)
# Requirement already satisfied: accelerate<2,>=0.34 in d:\conda_envs\my_env\Lib\site-packages (from chronos-forecasting) (1.13.0)
# Requirement already satisfied: einops<1,>=0.7.0 in d:\conda_envs\my_env\Lib\site-packages (from chronos-forecasting) (0.8.2)
# Requirement already satisfied: numpy<3,>=1.21 in d:\conda_envs\my_env\Lib\site-packages (from chronos-forecasting) (2.1.3)
# Requirement already satisfied: scikit-learn<2,>=1.6.0 in d:\conda_envs\my_env\Lib\site-packages (from chronos-forecasting) (1.7.2)
# Requirement already satisfied: torch<3,>=2.2 in d:\conda_envs\my_env\Lib\site-packages (from chronos-forecasting) (2.9.1)
# Requirement already satisfied: transformers<5,>=4.41 in d:\conda_envs\my_env\Lib\site-packages (from chronos-forecasting) (4.57.6)
# Requirement already satisfied: packaging>=20.0 in d:\conda_envs\my_env\Lib\site-packages (from accelerate<2,>=0.34->chronos-forecasting) (25.0)
# Requirement already satisfied: psutil in d:\conda_envs\my_env\Lib\site-packages (from accelerate<2,>=0.34->chronos-forecasting) (7.1.3)
# Requirement already satisfied: pyyaml in d:\conda_envs\my_env\Lib\site-packages (from accelerate<2,>=0.34->chronos-forecasting) (6.0.2)
# Requirement already satisfied: huggingface_hub>=0.21.0 in d:\conda_envs\my_env\Lib\site-packages (from accelerate<2,>=0.34->chronos-forecasting) (0.36.2)
# Requirement already satisfied: safetensors>=0.4.3 in d:\conda_envs\my_env\Lib\site-packages (from accelerate<2,>=0.34->chronos-forecasting) (0.7.0)
# Requirement already satisfied: scipy>=1.8.0 in d:\conda_envs\my_env\Lib\site-packages (from scikit-learn<2,>=1.6.0->chronos-forecasting) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\conda_envs\my_env\Lib\site-packages (from scikit-learn<2,>=1.6.0->chronos-forecasting) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\conda_envs\my_env\Lib\site-packages (from scikit-learn<2,>=1.6.0->chronos-forecasting) (3.6.0)
# Requirement already satisfied: filelock in d:\conda_envs\my_env\Lib\site-packages (from torch<3,>=2.2->chronos-forecasting) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\conda_envs\my_env\Lib\site-packages (from torch<3,>=2.2->chronos-forecasting) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\conda_envs\my_env\Lib\site-packages (from torch<3,>=2.2->chronos-forecasting) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in d:\conda_envs\my_env\Lib\site-packages (from torch<3,>=2.2->chronos-forecasting) (3.6.1)
# Requirement already satisfied: jinja2 in d:\conda_envs\my_env\Lib\site-packages (from torch<3,>=2.2->chronos-forecasting) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in d:\conda_envs\my_env\Lib\site-packages (from torch<3,>=2.2->chronos-forecasting) (2025.3.0)
# Requirement already satisfied: regex!=2019.12.17 in d:\conda_envs\my_env\Lib\site-packages (from transformers<5,>=4.41->chronos-forecasting) (2026.5.9)
# Requirement already satisfied: requests in d:\conda_envs\my_env\Lib\site-packages (from transformers<5,>=4.41->chronos-forecasting) (2.33.1)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in d:\conda_envs\my_env\Lib\site-packages (from transformers<5,>=4.41->chronos-forecasting) (0.22.2)
# Requirement already satisfied: tqdm>=4.27 in d:\conda_envs\my_env\Lib\site-packages (from transformers<5,>=4.41->chronos-forecasting) (4.68.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\conda_envs\my_env\Lib\site-packages (from sympy>=1.13.3->torch<3,>=2.2->chronos-forecasting) (1.3.0)
# Requirement already satisfied: colorama in d:\conda_envs\my_env\Lib\site-packages (from tqdm>=4.27->transformers<5,>=4.41->chronos-forecasting) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\conda_envs\my_env\Lib\site-packages (from jinja2->torch<3,>=2.2->chronos-forecasting) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\conda_envs\my_env\Lib\site-packages (from requests->transformers<5,>=4.41->chronos-forecasting) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\conda_envs\my_env\Lib\site-packages (from requests->transformers<5,>=4.41->chronos-forecasting) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\conda_envs\my_env\Lib\site-packages (from requests->transformers<5,>=4.41->chronos-forecasting) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in d:\conda_envs\my_env\Lib\site-packages (from requests->transformers<5,>=4.41->chronos-forecasting) (2026.4.22)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)

# %%
# %pip install torch transformers accelerate
# Out:
# Requirement already satisfied: torch in d:\conda_envs\my_env\Lib\site-packages (2.9.1)
# Requirement already satisfied: transformers in d:\conda_envs\my_env\Lib\site-packages (4.57.6)
# Requirement already satisfied: accelerate in d:\conda_envs\my_env\Lib\site-packages (1.13.0)
# Requirement already satisfied: filelock in d:\conda_envs\my_env\Lib\site-packages (from torch) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\conda_envs\my_env\Lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\conda_envs\my_env\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in d:\conda_envs\my_env\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in d:\conda_envs\my_env\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in d:\conda_envs\my_env\Lib\site-packages (from torch) (2025.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in d:\conda_envs\my_env\Lib\site-packages (from transformers) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in d:\conda_envs\my_env\Lib\site-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in d:\conda_envs\my_env\Lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\conda_envs\my_env\Lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in d:\conda_envs\my_env\Lib\site-packages (from transformers) (2026.5.9)
# Requirement already satisfied: requests in d:\conda_envs\my_env\Lib\site-packages (from transformers) (2.33.1)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in d:\conda_envs\my_env\Lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in d:\conda_envs\my_env\Lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in d:\conda_envs\my_env\Lib\site-packages (from transformers) (4.68.1)
# Requirement already satisfied: psutil in d:\conda_envs\my_env\Lib\site-packages (from accelerate) (7.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\conda_envs\my_env\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in d:\conda_envs\my_env\Lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\conda_envs\my_env\Lib\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\conda_envs\my_env\Lib\site-packages (from requests->transformers) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\conda_envs\my_env\Lib\site-packages (from requests->transformers) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\conda_envs\my_env\Lib\site-packages (from requests->transformers) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in d:\conda_envs\my_env\Lib\site-packages (from requests->transformers) (2026.4.22)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)

# %%
# %pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in d:\conda_envs\my_env\Lib\site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in d:\conda_envs\my_env\Lib\site-packages (from statsmodels) (2.1.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in d:\conda_envs\my_env\Lib\site-packages (from statsmodels) (1.16.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in d:\conda_envs\my_env\Lib\site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in d:\conda_envs\my_env\Lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in d:\conda_envs\my_env\Lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\conda_envs\my_env\Lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\conda_envs\my_env\Lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\conda_envs\my_env\Lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2026.2)
# Requirement already satisfied: six>=1.5 in d:\conda_envs\my_env\Lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)

# %%
# %pip install feature-engine
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (d:\conda_envs\my_env\Lib\site-packages)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.org', port=443): Failed to resolve 'pypi.org' ([Errno 11001] getaddrinfo failed)")': /simple/feature-engine/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.org', port=443): Failed to resolve 'pypi.org' ([Errno 11001] getaddrinfo failed)")': /simple/feature-engine/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.org', port=443): Failed to resolve 'pypi.org' ([Errno 11001] getaddrinfo failed)")': /simple/feature-engine/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.org', port=443): Failed to resolve 'pypi.org' ([Errno 11001] getaddrinfo failed)")': /simple/feature-engine/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.org', port=443): Failed to resolve 'pypi.org' ([Errno 11001] getaddrinfo failed)")': /simple/feature-engine/
# ERROR: Could not find a version that satisfies the requirement feature-engine (from versions: none)
# ERROR: No matching distribution found for feature-engine

# %%
# !pip install --force-reinstall scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting numpy<2.7,>=1.26.4 (from scipy)
#   Downloading numpy-2.4.6-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl (36.6 MB)
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.6 MB ? eta -:--:--
#     --------------------------------------- 0.5/36.6 MB 762.0 kB/s eta 0:00:48
#     --------------------------------------- 0.8/36.6 MB 1.0 MB/s eta 0:00:35
#    - -------------------------------------- 1.0/36.6 MB 1.1 MB/s eta 0:00:33
#    - -------------------------------------- 1.3/36.6 MB 1.1 MB/s eta 0:00:34
#    - -------------------------------------- 1.6/36.6 MB 1.1 MB/s eta 0:00:32
#    -- ------------------------------------- 1.8/36.6 MB 1.2 MB/s eta 0:00:30
#    -- ------------------------------------- 2.4/36.6 MB 1.3 MB/s eta 0:00:27
#    -- ------------------------------------- 2.6/36.6 MB 1.3 MB/s eta 0:00:28
#    -- ------------------------------------- 2.6/36.6 MB 1.3 MB/s eta 0:00:28
#    --- ------------------------------------ 3.1/36.6 MB 1.2 MB/s eta 0:00:27
#    --- ------------------------------------ 3.4/36.6 MB 1.3 MB/s eta 0:00:27
#    ---- ----------------------------------- 3.7/36.6 MB 1.3 MB/s eta 0:00:27
#    ---- ----------------------------------- 3.9/36.6 MB 1.3 MB/s eta 0:00:26
#    ---- ----------------------------------- 3.9/36.6 MB 1.3 MB/s eta 0:00:26
#    ---- ----------------------------------- 4.2/36.6 MB 1.2 MB/s eta 0:00:27
#    ---- ----------------------------------- 4.5/36.6 MB 1.2 MB/s eta 0:00:27
#    ----- ---------------------------------- 4.7/36.6 MB 1.2 MB/s eta 0:00:27
#    ----- ---------------------------------- 5.0/36.6 MB 1.2 MB/s eta 0:00:28
#    ----- ---------------------------------- 5.0/36.6 MB 1.2 MB/s eta 0:00:28
#    ----- ---------------------------------- 5.2/36.6 MB 1.2 MB/s eta 0:00:28
#    ------ --------------------------------- 5.5/36.6 MB 1.1 MB/s eta 0:00:28
#    ------ --------------------------------- 5.5/36.6 MB 1.1 MB/s eta 0:00:28
#    ------ --------------------------------- 5.8/36.6 MB 1.1 MB/s eta 0:00:28
#    ------ --------------------------------- 6.0/36.6 MB 1.1 MB/s eta 0:00:28
#    ------- -------------------------------- 6.6/36.6 MB 1.1 MB/s eta 0:00:27
#    ------- -------------------------------- 6.8/36.6 MB 1.2 MB/s eta 0:00:26
#    -------- ------------------------------- 7.3/36.6 MB 1.2 MB/s eta 0:00:25
#    -------- ------------------------------- 7.6/36.6 MB 1.2 MB/s eta 0:00:25
#    -------- ------------------------------- 7.9/36.6 MB 1.2 MB/s eta 0:00:24
#    -------- ------------------------------- 8.1/36.6 MB 1.2 MB/s eta 0:00:24
#    --------- ------------------------------ 8.4/36.6 MB 1.2 MB/s eta 0:00:24
#    --------- ------------------------------ 8.4/36.6 MB 1.2 MB/s eta 0:00:24
#    --------- ------------------------------ 8.7/36.6 MB 1.2 MB/s eta 0:00:24
#    --------- ------------------------------ 8.7/36.6 MB 1.2 MB/s eta 0:00:24
#    --------- ------------------------------ 8.9/36.6 MB 1.1 MB/s eta 0:00:25
#    ---------- ----------------------------- 9.2/36.6 MB 1.1 MB/s eta 0:00:25
#    ---------- ----------------------------- 9.2/36.6 MB 1.1 MB/s eta 0:00:25
#    ---------- ----------------------------- 9.4/36.6 MB 1.1 MB/s eta 0:00:25
#    ---------- ----------------------------- 10.0/36.6 MB 1.1 MB/s eta 0:00:24
#    ---------- ----------------------------- 10.0/36.6 MB 1.1 MB/s eta 0:00:24
#    ----------- ---------------------------- 10.2/36.6 MB 1.1 MB/s eta 0:00:24
#    ----------- ---------------------------- 10.5/36.6 MB 1.1 MB/s eta 0:00:24
#    ----------- ---------------------------- 10.7/36.6 MB 1.1 MB/s eta 0:00:24
#    ------------ --------------------------- 11.0/36.6 MB 1.1 MB/s eta 0:00:23
#    ------------ --------------------------- 11.5/36.6 MB 1.1 MB/s eta 0:00:22
#    ------------ --------------------------- 11.8/36.6 MB 1.2 MB/s eta 0:00:22
#    ------------- -------------------------- 12.3/36.6 MB 1.2 MB/s eta 0:00:21
#    ------------- -------------------------- 12.6/36.6 MB 1.2 MB/s eta 0:00:21
#    -------------- ------------------------- 12.8/36.6 MB 1.2 MB/s eta 0:00:21
#    -------------- ------------------------- 13.1/36.6 MB 1.2 MB/s eta 0:00:20
#    -------------- ------------------------- 13.6/36.6 MB 1.2 MB/s eta 0:00:19
#    --------------- ------------------------ 13.9/36.6 MB 1.2 MB/s eta 0:00:19
#    ---------------- ----------------------- 14.7/36.6 MB 1.3 MB/s eta 0:00:18
#    ---------------- ----------------------- 15.2/36.6 MB 1.3 MB/s eta 0:00:17
#    ---------------- ----------------------- 15.5/36.6 MB 1.3 MB/s eta 0:00:17
#    ----------------- ---------------------- 15.7/36.6 MB 1.3 MB/s eta 0:00:17
#    ----------------- ---------------------- 15.7/36.6 MB 1.3 MB/s eta 0:00:17
#    ----------------- ---------------------- 16.0/36.6 MB 1.3 MB/s eta 0:00:17
#    ----------------- ---------------------- 16.0/36.6 MB 1.3 MB/s eta 0:00:17
#    ----------------- ---------------------- 16.3/36.6 MB 1.2 MB/s eta 0:00:17
#    ----------------- ---------------------- 16.3/36.6 MB 1.2 MB/s eta 0:00:17
#    ----------------- ---------------------- 16.3/36.6 MB 1.2 MB/s eta 0:00:17
#    ------------------ --------------------- 16.5/36.6 MB 1.2 MB/s eta 0:00:17
#    ------------------ --------------------- 16.5/36.6 MB 1.2 MB/s eta 0:00:17
#    ------------------ --------------------- 17.0/36.6 MB 1.2 MB/s eta 0:00:17
#    ------------------ --------------------- 17.0/36.6 MB 1.2 MB/s eta 0:00:17
#    ------------------ --------------------- 17.0/36.6 MB 1.2 MB/s eta 0:00:17
#    ------------------ --------------------- 17.3/36.6 MB 1.2 MB/s eta 0:00:17
#    ------------------ --------------------- 17.3/36.6 MB 1.2 MB/s eta 0:00:17
#    ------------------- -------------------- 17.6/36.6 MB 1.2 MB/s eta 0:00:17
#    ------------------- -------------------- 17.6/36.6 MB 1.2 MB/s eta 0:00:17
#    ------------------- -------------------- 17.8/36.6 MB 1.1 MB/s eta 0:00:17
#    ------------------- -------------------- 17.8/36.6 MB 1.1 MB/s eta 0:00:17
#    ------------------- -------------------- 18.1/36.6 MB 1.1 MB/s eta 0:00:17
#    -------------------- ------------------- 18.6/36.6 MB 1.1 MB/s eta 0:00:16
#    -------------------- ------------------- 18.9/36.6 MB 1.1 MB/s eta 0:00:16
#    -------------------- ------------------- 18.9/36.6 MB 1.1 MB/s eta 0:00:16
#    -------------------- ------------------- 18.9/36.6 MB 1.1 MB/s eta 0:00:16
#    -------------------- ------------------- 19.1/36.6 MB 1.1 MB/s eta 0:00:16
#    -------------------- ------------------- 19.1/36.6 MB 1.1 MB/s eta 0:00:16
#    --------------------- ------------------ 19.4/36.6 MB 1.1 MB/s eta 0:00:16
#    --------------------- ------------------ 19.7/36.6 MB 1.1 MB/s eta 0:00:16
#    --------------------- ------------------ 19.7/36.6 MB 1.1 MB/s eta 0:00:16
#    ---------------------- ----------------- 20.2/36.6 MB 1.1 MB/s eta 0:00:15
#    ---------------------- ----------------- 20.7/36.6 MB 1.1 MB/s eta 0:00:15
#    ---------------------- ----------------- 20.7/36.6 MB 1.1 MB/s eta 0:00:15
#    ---------------------- ----------------- 21.0/36.6 MB 1.1 MB/s eta 0:00:15
#    ---------------------- ----------------- 21.0/36.6 MB 1.1 MB/s eta 0:00:15
#    ----------------------- ---------------- 21.2/36.6 MB 1.1 MB/s eta 0:00:15
#    ----------------------- ---------------- 21.5/36.6 MB 1.1 MB/s eta 0:00:14
#    ----------------------- ---------------- 21.5/36.6 MB 1.1 MB/s eta 0:00:14
#    ----------------------- ---------------- 21.8/36.6 MB 1.1 MB/s eta 0:00:14
#    ------------------------ --------------- 22.0/36.6 MB 1.1 MB/s eta 0:00:14
#    ------------------------ --------------- 22.0/36.6 MB 1.1 MB/s eta 0:00:14
#    ------------------------ --------------- 22.0/36.6 MB 1.1 MB/s eta 0:00:14
#    ------------------------ --------------- 22.3/36.6 MB 1.1 MB/s eta 0:00:14
#    ------------------------ --------------- 22.3/36.6 MB 1.1 MB/s eta 0:00:14
#    ------------------------ --------------- 22.5/36.6 MB 1.1 MB/s eta 0:00:14
#    ------------------------ --------------- 22.5/36.6 MB 1.1 MB/s eta 0:00:14
#    ------------------------ --------------- 22.5/36.6 MB 1.1 MB/s eta 0:00:14
#    ------------------------ --------------- 22.8/36.6 MB 1.0 MB/s eta 0:00:14
#    ------------------------- -------------- 23.1/36.6 MB 1.0 MB/s eta 0:00:14
#    ------------------------- -------------- 23.3/36.6 MB 1.0 MB/s eta 0:00:13
#    ------------------------- -------------- 23.3/36.6 MB 1.0 MB/s eta 0:00:13
#    ------------------------- -------------- 23.6/36.6 MB 1.0 MB/s eta 0:00:13
#    ------------------------- -------------- 23.6/36.6 MB 1.0 MB/s eta 0:00:13
#    -------------------------- ------------- 23.9/36.6 MB 1.0 MB/s eta 0:00:13
#    -------------------------- ------------- 23.9/36.6 MB 1.0 MB/s eta 0:00:13
#    -------------------------- ------------- 23.9/36.6 MB 1.0 MB/s eta 0:00:13
#    -------------------------- ------------- 24.1/36.6 MB 1.0 MB/s eta 0:00:13
#    -------------------------- ------------- 24.4/36.6 MB 1.0 MB/s eta 0:00:13
#    -------------------------- ------------- 24.6/36.6 MB 1.0 MB/s eta 0:00:12
#    --------------------------- ------------ 24.9/36.6 MB 1.0 MB/s eta 0:00:12
#    --------------------------- ------------ 25.2/36.6 MB 1.0 MB/s eta 0:00:12
#    --------------------------- ------------ 25.4/36.6 MB 1.0 MB/s eta 0:00:11
#    ---------------------------- ----------- 25.7/36.6 MB 1.0 MB/s eta 0:00:11
#    ---------------------------- ----------- 26.0/36.6 MB 1.0 MB/s eta 0:00:11
#    ---------------------------- ----------- 26.0/36.6 MB 1.0 MB/s eta 0:00:11
#    ---------------------------- ----------- 26.2/36.6 MB 1.0 MB/s eta 0:00:11
#    ---------------------------- ----------- 26.2/36.6 MB 1.0 MB/s eta 0:00:11
#    ---------------------------- ----------- 26.5/36.6 MB 1.0 MB/s eta 0:00:11
#    ----------------------------- ---------- 26.7/36.6 MB 1.0 MB/s eta 0:00:10
#    ----------------------------- ---------- 27.0/36.6 MB 1.0 MB/s eta 0:00:10
#    ----------------------------- ---------- 27.0/36.6 MB 1.0 MB/s eta 0:00:10
#    ----------------------------- ---------- 27.3/36.6 MB 1.0 MB/s eta 0:00:10
#    ------------------------------ --------- 27.5/36.6 MB 1.0 MB/s eta 0:00:09
#    ------------------------------ --------- 27.8/36.6 MB 1.0 MB/s eta 0:00:09
#    ------------------------------ --------- 28.0/36.6 MB 1.0 MB/s eta 0:00:09
#    ------------------------------ --------- 28.3/36.6 MB 1.0 MB/s eta 0:00:09
#    ------------------------------- -------- 28.6/36.6 MB 1.0 MB/s eta 0:00:08
#    ------------------------------- -------- 29.1/36.6 MB 1.0 MB/s eta 0:00:08
#    -------------------------------- ------- 29.4/36.6 MB 1.0 MB/s eta 0:00:08
#    -------------------------------- ------- 29.6/36.6 MB 1.0 MB/s eta 0:00:07
#    -------------------------------- ------- 30.1/36.6 MB 1.0 MB/s eta 0:00:07
#    --------------------------------- ------ 30.4/36.6 MB 1.0 MB/s eta 0:00:06
#    --------------------------------- ------ 30.7/36.6 MB 1.0 MB/s eta 0:00:06
#    --------------------------------- ------ 30.9/36.6 MB 1.0 MB/s eta 0:00:06
#    ---------------------------------- ----- 31.2/36.6 MB 1.0 MB/s eta 0:00:06
#    ---------------------------------- ----- 31.2/36.6 MB 1.0 MB/s eta 0:00:06
#    ---------------------------------- ----- 31.5/36.6 MB 1.0 MB/s eta 0:00:05
#    ---------------------------------- ----- 31.7/36.6 MB 1.0 MB/s eta 0:00:05
#    ---------------------------------- ----- 31.7/36.6 MB 1.0 MB/s eta 0:00:05
#    ---------------------------------- ----- 32.0/36.6 MB 1.0 MB/s eta 0:00:05
#    ----------------------------------- ---- 32.2/36.6 MB 1.0 MB/s eta 0:00:05
#    ----------------------------------- ---- 32.5/36.6 MB 1.0 MB/s eta 0:00:05
#    ----------------------------------- ---- 32.5/36.6 MB 1.0 MB/s eta 0:00:05
#    ----------------------------------- ---- 32.8/36.6 MB 1.0 MB/s eta 0:00:04
#    ------------------------------------ --- 33.0/36.6 MB 1.0 MB/s eta 0:00:04
#    ------------------------------------ --- 33.3/36.6 MB 1.0 MB/s eta 0:00:04
#    ------------------------------------ --- 33.8/36.6 MB 1.0 MB/s eta 0:00:03
#    ------------------------------------- -- 34.3/36.6 MB 1.0 MB/s eta 0:00:03
#    -------------------------------------- - 34.9/36.6 MB 1.0 MB/s eta 0:00:02
#    -------------------------------------- - 35.4/36.6 MB 1.1 MB/s eta 0:00:02
#    ---------------------------------------  35.9/36.6 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.6 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 36.6/36.6 MB 1.1 MB/s  0:00:34
# Downloading numpy-2.4.6-cp311-cp311-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.6 MB 4.8 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.6/12.6 MB 5.2 MB/s eta 0:00:03
#    ------ --------------------------------- 2.1/12.6 MB 3.9 MB/s eta 0:00:03
#    --------- ------------------------------ 2.9/12.6 MB 3.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.4/12.6 MB 3.3 MB/s eta 0:00:03
#    ------------- -------------------------- 4.2/12.6 MB 3.5 MB/s eta 0:00:03
#    --------------- ------------------------ 5.0/12.6 MB 3.5 MB/s eta 0:00:03
#    ------------------ --------------------- 5.8/12.6 MB 3.4 MB/s eta 0:00:03
#    ------------------- -------------------- 6.0/12.6 MB 3.5 MB/s eta 0:00:02
#    --------------------- ------------------ 6.8/12.6 MB 3.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.1/12.6 MB 3.1 MB/s eta 0:00:02
#    ------------------------ --------------- 7.9/12.6 MB 3.2 MB/s eta 0:00:02
#    ------------------------- -------------- 8.1/12.6 MB 3.0 MB/s eta 0:00:02
#    --------------------------- ------------ 8.7/12.6 MB 3.0 MB/s eta 0:00:02
#    ------------------------------ --------- 9.7/12.6 MB 3.1 MB/s eta 0:00:01
#    -------------------------------- ------- 10.2/12.6 MB 3.0 MB/s eta 0:00:01
#    --------------------------------- ------ 10.5/12.6 MB 3.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.3/12.6 MB 3.0 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.6 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 2.9 MB/s  0:00:04
# Installing collected packages: numpy, scipy
#
#   Attempting uninstall: numpy
#
#     Found existing installation: numpy 2.1.3
#
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#     Uninstalling numpy-2.1.3:
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#       Successfully uninstalled numpy-2.1.3
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#   Attempting uninstall: scipy
#    ---------------------------------------- 0/2 [numpy]
#     Found existing installation: scipy 1.16.3
#    ---------------------------------------- 0/2 [numpy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#     Uninstalling scipy-1.16.3:
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#       Successfully uninstalled scipy-1.16.3
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    -------------------- ------------------- 1/2 [scipy]
#    ---------------------------------------- 2/2 [scipy]
#
# Successfully installed numpy-2.4.6 scipy-1.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-common 1.5.0 requires numpy<2.4.0,>=1.25.0, but you have numpy 2.4.6 which is incompatible.
# autogluon-core 1.5.0 requires numpy<2.4.0,>=1.25.0, but you have numpy 2.4.6 which is incompatible.
# autogluon-core 1.5.0 requires scipy<1.17,>=1.5.4, but you have scipy 1.17.1 which is incompatible.
# autogluon-features 1.5.0 requires numpy<2.4.0,>=1.25.0, but you have numpy 2.4.6 which is incompatible.
# autogluon-multimodal 1.5.0 requires numpy<2.4.0,>=1.25.0, but you have numpy 2.4.6 which is incompatible.
# autogluon-multimodal 1.5.0 requires scipy<1.17,>=1.5.4, but you have scipy 1.17.1 which is incompatible.
# autogluon-tabular 1.5.0 requires numpy<2.4.0,>=1.25.0, but you have numpy 2.4.6 which is incompatible.
# autogluon-tabular 1.5.0 requires scipy<1.17,>=1.5.4, but you have scipy 1.17.1 which is incompatible.
# autogluon-timeseries 1.5.0 requires numpy<2.4.0,>=1.25.0, but you have numpy 2.4.6 which is incompatible.
# autogluon-timeseries 1.5.0 requires scipy<1.17,>=1.5.4, but you have scipy 1.17.1 which is incompatible.
# gluonts 0.16.2 requires numpy<2.2,>=1.16, but you have numpy 2.4.6 which is incompatible.
# mistral-common 1.11.3 requires numpy<2.4,>=1.25; python_version <= "3.12", but you have numpy 2.4.6 which is incompatible.
# paddlex 3.6.1 requires numpy<2.4,>=1.24, but you have numpy 2.4.6 which is incompatible.

# %%
# !pip install -q pandas numpy matplotlib seaborn scikit-learn statsmodels xgboost lightgbm torch autogluon shap optuna transformers accelerate chronos-forecasting tqdm

# %%
# !pip install -q tensorflow
